# %% [markdown]
# <a href="https://colab.research.google.com/github/luogonannita-design/Machine-Learning-with-Python-Boot-Camp-/blob/main/Week_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Annita Luogon - 25 May 2026
# problem 1
# it prints 1847 and Liberia
Liberia=1847
print(Liberia)
print("Liberia")

# problem 2
# Country is a variable
#the second print is a full sentence using the variable
Country = "Liberia"
print(Country)
print(Country, "became independent in 1847")

#problem 3
#I used a single quotation mark for the full sentence because they're strings
#I used the double quotation mark for the 1847 to follow the instruction
print('The year is "1847"')

#Problem 4
#this problem is for printing variables and data types
#these data types are strings, integers, floats and boolean
market_name ="Gobachop Market"
total_market_table = 150
price_per_bag =3200.50
is_market_open = True
print(type(market_name))
print(type(total_market_table))
print(type(price_per_bag))
print(type(is_market_open))

#Problem 5
#storing the current price
Current_price = 2550.75
#storing the quantity
Quantity = 10
#Calculate total cost
total_cost = Current_price * Quantity
print("Total cost for 10 bags:",total_cost, "LRD")

#Problem 6
#the first line is storing whether has_scarcity is fasle
#the second line is storing whether is_rainy is true
#they're both boolean data type
has_scarcity = False
is_rainy = True
print("Scarcity today", has_scarcity)
print("Rainy today", is_rainy)

#Problem 7
#storing the price of one bag
price_per_bag = 800
#storing the quantity that was bought
Quantity = 25
#Calculating the total revenue
total_revenue = price_per_bag * Quantity
print("Total revenue is", total_revenue, "LRD")

#Problem 8
#storing today's price
Today_price = 3200
#storing the amount it's increasing to
Increase = 150
#Calculating tomorrow's price
Tomorrow_price = Today_price + Increase
print("Tomorrow rice price is:", Tomorrow_price,"LRD")

#Problem 9
#Storing the total cost
total_cost = 1800
#storing the number of traders
number_of_traders = 3
#Calculating the cost per traders
cost_per_trader = total_cost/ number_of_traders
print("cost per trader is:", cost_per_trader, "LRD")

#Problem 10
#Storing the original price
Original_price = 2500
#storing the discount rate
Discount_rate =0.10
#calculating the discount amount
Discount_amount = Original_price * Discount_rate
#calculating the final price
Final_price = Original_price - Discount_amount
print("Discount amount:", Discount_amount,"LRD")
print("final price:", Final_price,"LRD")

#Problem 11
#storing values in variables
Items = "Cassava"
price = 800
print(Items)
print("Item")
print(price)
print("price")
#the answer is cassava,Item, 800, and price
#first print is the variable for cassava
#the second print is a text
#the third print is also the variable for 800
#the last print is also a text


#Problem 12
#storing a product name
Product = "pepper"
#storing the cost of the pepper
Cost = 150.50
print("One bag of", Product, "costs",Cost,"LRD")
# Out:
# 1847
# Liberia
# Liberia
# Liberia became independent in 1847
# The year is "1847"
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# Total cost for 10 bags: 25507.5 LRD
# Scarcity today False
# Rainy today True
# Total revenue is 20000 LRD
# Tomorrow rice price is: 3350 LRD
# cost per trader is: 600.0 LRD
# Discount amount: 250.0 LRD
# final price: 2250.0 LRD
# Cassava
# Item
# 800
# price
# One bag of pepper costs 150.5 LRD
